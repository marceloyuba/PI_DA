# %%
import pandas as pd

# %% [markdown]
# ### Leemos el dataset y traemos las tablas necesarias

# %%
df_hechos = pd.read_excel('homicidios.xlsx',sheet_name='HECHOS')

# %%
df_victimas = pd.read_excel('homicidios.xlsx', sheet_name='VICTIMAS')

# %% [markdown]
# ### Tabla de `Hechos`

# %%
df_hechos
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA    HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4.0
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1.0
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7.0
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0.0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5.0
# ..         ...         ...        ...   ...  ..  ..       ...   ...
# 691  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17.0
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1.0
# 693  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0.0
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10.0
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6.0
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# ...

# %% [markdown]
# ### Tabla de `Hechos`

# %% [markdown]
# ### Eliminamos las columnas que no van a ser usadas

# %%
df_hechos.drop(['XY (CABA)', 'pos x', 'pos y','PARTICIPANTES','LUGAR_DEL_HECHO', 'Dirección Normalizada'], axis=1, inplace=True)

# %%
df_hechos
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA    HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4.0
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1.0
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7.0
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0.0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5.0
# ..         ...         ...        ...   ...  ..  ..       ...   ...
# 691  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17.0
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1.0
# 693  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0.0
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10.0
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6.0
#
#     TIPO_DE_CALLE                         Calle  Altura  \
# 0         AVENIDA              PIEDRA BUENA AV.     NaN
# ...

# %% [markdown]
# ### Reemplzamos los nombres de las columnas

# %%
df_hechos = df_hechos.rename(columns={'ID': 'Id','N_VICTIMAS':'Victimas', 'FECHA':'Fecha', 'AAAA':'Año', 'MM':'Mes', 'DD':'Dia', 'HORA':'Hora',	'HH':'Franja_horaria',  'TIPO_DE_CALLE':'Tipo_de_via', 'COMUNA':'Comuna', 'VICTIMA':'Victima', 'ACUSADO':'Acusado'})

# %%
df_hechos
# Out:
#             Id  Victimas      Fecha   Año  Mes  Dia      Hora  Franja_horaria  \
# 0    2016-0001         1 2016-01-01  2016    1    1  04:00:00             4.0
# 1    2016-0002         1 2016-01-02  2016    1    2  01:15:00             1.0
# 2    2016-0003         1 2016-01-03  2016    1    3  07:00:00             7.0
# 3    2016-0004         1 2016-01-10  2016    1   10  00:00:00             0.0
# 4    2016-0005         1 2016-01-21  2016    1   21  05:20:00             5.0
# ..         ...       ...        ...   ...  ...  ...       ...             ...
# 691  2021-0093         1 2021-12-13  2021   12   13  17:10:00            17.0
# 692  2021-0094         1 2021-12-20  2021   12   20  01:10:00             1.0
# 693  2021-0095         1 2021-12-30  2021   12   30  00:43:00             0.0
# 694  2021-0096         1 2021-12-15  2021   12   15  10:30:00            10.0
# 695  2021-0097         1 2021-11-18  2021   11   18  06:10:00             6.0
#
# ...

# %% [markdown]
# ### Tabla de `Victimas`

# %%
df_victimas
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0    2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1    2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2    2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3    2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4    2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# ..         ...        ...   ...  ..  ..                   ...     ...
# 712  2021-0092 2021-12-12  2021  12  12                PEATON  PEATON
# 713  2021-0093 2021-12-13  2021  12  13  PASAJERO_ACOMPAÑANTE    MOTO
# 714  2021-0094 2021-12-20  2021  12  20  PASAJERO_ACOMPAÑANTE    MOTO
# 715  2021-0095 2021-12-30  2021  12  30             CONDUCTOR    MOTO
# 716  2021-0096 2021-12-15  2021  12  15             CONDUCTOR    AUTO
#
#           SEXO EDAD  FECHA_FALLECIMIENTO
# 0    MASCULINO   19  2016-01-01 00:00:00
# 1    MASCULINO   70  2016-01-02 00:00:00
# ...

# %% [markdown]
# ### Reemplzamos los nombres de las columnas

# %%
df_victimas = df_victimas.rename(columns={'ID_hecho': 'Id','N_VICTIMAS':'Victimas', 'FECHA':'Fecha', 'AAAA':'Año', 'MM':'Mes', 'DD':'Dia', 'HORA':'Hora',	'ROL':'Rol', 'VICTIMA':'Victima', 'SEXO':'Sexo', 'EDAD':'Edad','FECHA_FALLECIMIENTO':'Fallecimiento'})

# %%
df_victimas
# Out:
#             Id      Fecha   Año  Mes  Dia                   Rol Victima  \
# 0    2016-0001 2016-01-01  2016    1    1             CONDUCTOR    MOTO
# 1    2016-0002 2016-01-02  2016    1    2             CONDUCTOR    AUTO
# 2    2016-0003 2016-01-03  2016    1    3             CONDUCTOR    MOTO
# 3    2016-0004 2016-01-10  2016    1   10             CONDUCTOR    MOTO
# 4    2016-0005 2016-01-21  2016    1   21             CONDUCTOR    MOTO
# ..         ...        ...   ...  ...  ...                   ...     ...
# 712  2021-0092 2021-12-12  2021   12   12                PEATON  PEATON
# 713  2021-0093 2021-12-13  2021   12   13  PASAJERO_ACOMPAÑANTE    MOTO
# 714  2021-0094 2021-12-20  2021   12   20  PASAJERO_ACOMPAÑANTE    MOTO
# 715  2021-0095 2021-12-30  2021   12   30             CONDUCTOR    MOTO
# 716  2021-0096 2021-12-15  2021   12   15             CONDUCTOR    AUTO
#
#           Sexo Edad        Fallecimiento
# 0    MASCULINO   19  2016-01-01 00:00:00
# ...

# %%
df_victimas.to_csv('Victimas.csv', index=False)

# %%
df_hechos.to_csv('Hechos.csv', index=False)
